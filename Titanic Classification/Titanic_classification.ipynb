# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Titanic-Dataset.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
def delete_object(data):
    for i in data.columns:
        missing_percentage = data[i].isnull().sum() / len(data) * 100
        if missing_percentage > 50:
            data.drop([i], axis = 1, inplace = True)

    return data

delete_object(df)

df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [891 rows x 11 columns]

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize = [10, 5])
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 5>()
#       2 import seaborn as sns
#       4 plt.figure(figsize = [10, 5])
# ----> 5 sns.heatmap(df.corr(numeric_only=True), annot=True)
#
# TypeError: corr() got an unexpected keyword argument 'numeric_only'

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
def label_encoder(data):
    for i in data.columns:
        if data[i].dtype == "object":
            data[i] = le.fit_transform(data[i])
            
label_encoder(df)
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              1         0       3   108    1  22.0      1      0     523
# 1              2         1       1   190    0  38.0      1      0     596
# 2              3         1       3   353    0  26.0      0      0     669
# 3              4         1       1   272    0  35.0      1      0      49
# 4              5         0       3    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          887         0       2   548    1  27.0      0      0     101
# 887          888         1       1   303    0  19.0      0      0      14
# 888          889         0       3   413    0   NaN      1      2     675
# 889          890         1       1    81    1  26.0      0      0       8
# 890          891         0       3   220    1  32.0      0      0     466
#
#         Fare  Embarked
# 0     7.2500         2
# 1    71.2833         0
# 2     7.9250         2
# 3    53.1000         2
# 4     8.0500         2
# ..       ...       ...
# 886  13.0000         2
# 887  30.0000         2
# 888  23.4500         2
# 889  30.0000         0
# 890   7.7500         1
#
# [891 rows x 11 columns]

# %%
#Handle missing values

def handle_missing(data):
    for i in data.columns:
        if data[i].isnull().any():
            data[i].fillna(np.mean(df[i]), inplace = True)
            
handle_missing(df)

df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
#Scaling function
from sklearn.preprocessing import MinMaxScaler
def scaling_function(data):
    scaler = MinMaxScaler()
    scaled_data = scaler.fit_transform(data)

    return scaled_data

# %%
#Split our target column
y = df["Survived"]
#Remove the unnecessary column 
x = df.drop(["Name", "Survived"], axis = 1)
scaled_x = scaling_function(x)

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    #tf.keras.layers.Dense(units = 128, activation = "relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(units = 64, activation = "relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(units = 32, activation = "relu", kernel_regularizer=tf.keras.regularizers.l2(0.01)),
    tf.keras.layers.Dense(units = 1, activation = "sigmoid")
])

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate=0.001), loss = tf.keras.losses.BinaryCrossentropy(), metrics = "accuracy")
model.fit(scaled_x, y, validation_data = (scaled_x, y), epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 4s 27ms/step - loss: 1.1616 - accuracy: 0.6162 - val_loss: 1.0587 - val_accuracy: 0.6162
# Epoch 2/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.9868 - accuracy: 0.6364 - val_loss: 0.9138 - val_accuracy: 0.7059
# Epoch 3/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.8572 - accuracy: 0.7632 - val_loss: 0.8021 - val_accuracy: 0.7800
# Epoch 4/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.7636 - accuracy: 0.7688 - val_loss: 0.7233 - val_accuracy: 0.7823
# Epoch 5/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.6973 - accuracy: 0.7868 - val_loss: 0.6674 - val_accuracy: 0.7868
# Epoch 6/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.6485 - accuracy: 0.7823 - val_loss: 0.6289 - val_accuracy: 0.7868
# Epoch 7/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.6157 - accuracy: 0.7868 - val_loss: 0.5964 - val_accuracy: 0.7868
# Epoch 8/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0
100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4660 - accuracy: 0.8081 - val_loss: 0.4633 - val_accuracy: 0.8126
# Epoch 72/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4650 - accuracy: 0.8070 - val_loss: 0.4641 - val_accuracy: 0.8171
# Epoch 73/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4657 - accuracy: 0.8126 - val_loss: 0.4630 - val_accuracy: 0.8092
# Epoch 74/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4669 - accuracy: 0.8047 - val_loss: 0.4629 - val_accuracy: 0.8114
# Epoch 75/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4686 - accuracy: 0.8036 - val_loss: 0.4678 - val_accuracy: 0.8171
# Epoch 76/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4714 - accuracy: 0.7969 - val_loss: 0.4644 - val_accuracy: 0.8182
# Epoch 77/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4654 - accuracy: 0.8126 - val_loss: 0.4630 - val_accuracy: 0.8114
# Epoch 78/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4638 - accuracy: 0.8081 - val_loss: 0.4644 - val_accuracy: 0.8002
# Epoch 79/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4654 - accuracy: 0.8171 - val_loss: 0.4621 - val_accuracy: 0.8103
# Epoch 80/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4659 - accuracy: 0.8070 - val_loss: 0.4626 - val_accuracy: 0.8092
# Epoch 81/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4637 - accuracy: 0.8126 - val_loss: 0.4618 - val_accuracy: 0.8103
# Epoch 82/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4634 - accuracy: 0.8103 - val_loss: 0.4614 - val_accuracy: 0.8126
# Epoch 83/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4638 - accuracy: 0.8070 - val_loss: 0.4614 - val_accuracy: 0.8081
# Epoch 84/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4643 - accuracy: 0.8092 - val_loss: 0.4617 - val_accuracy: 0.8215
# Epoch 85/100
# 28/28 [==============================] - 0s 5ms/step - loss: 0.4657 - accuracy: 0.8002 - val_loss: 0.4633 - val_accuracy: 0.8159
# Epoch 86/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4630 - accuracy: 0.8114 - val_loss: 0.4608 - val_accuracy: 0.8103
# Epoch 87/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4651 - accuracy: 0.8058 - val_loss: 0.4666 - val_accuracy: 0.8137
# Epoch 88/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4638 - accuracy: 0.8126 - val_loss: 0.4608 - val_accuracy: 0.8081
# Epoch 89/100
# 28/28 [==============================] - 0s 6ms/step - loss: 0.4628 - accuracy: 0.8126 - val_loss: 0.4605 - val_accuracy: 0.8159
# Epoch 90/100
# 28/28 [==============================] - 0s 9ms/step - loss: 0.4667 - accuracy: 0.8126 - val_loss: 0.4700 - val_accuracy: 0.8070
# Epoch 91/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4681 - accuracy: 0.7991 - val_loss: 0.4624 - val_accuracy: 0.8148
# Epoch 92/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4625 - accuracy: 0.8070 - val_loss: 0.4602 - val_accuracy: 0.8137
# Epoch 93/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4614 - accuracy: 0.8081 - val_loss: 0.4602 - val_accuracy: 0.8193
# Epoch 94/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4623 - accuracy: 0.8114 - val_loss: 0.4608 - val_accuracy: 0.8047
# Epoch 95/100
# 28/28 [==============================] - 0s 10ms/step - loss: 0.4624 - accuracy: 0.8081 - val_loss: 0.4599 - val_accuracy: 0.8171
# Epoch 96/100
# 28/28 [==============================] - 0s 8ms/step - loss: 0.4617 - accuracy: 0.8036 - val_loss: 0.4595 - val_accuracy: 0.8103
# Epoch 97/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4614 - accuracy: 0.8092 - val_loss: 0.4617 - val_accuracy: 0.8148
# Epoch 98/100
# 28/28 [==============================] - 0s 7ms/step - loss: 0.4621 - accuracy: 0.8070 - val_loss: 0.4591 - val_accuracy: 0.8148
# Epoch 99/100
# 28/28 [==============================] - 0s 9ms/step - loss: 0.4617 - accuracy: 0.8013 - val_loss: 0.4590 - val_accuracy: 0.8103
# Epoch 100/100
# 28/28 [==============================] - 0s 9ms/step - loss: 0.4609 - accuracy: 0.8081 - val_loss: 0.4589 - val_accuracy: 0.8126

# %%
loss, accuracy = model.evaluate(scaled_x, y)

print("Loss:", loss)
print("Accuracy:", accuracy)
# Out:
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4589 - accuracy: 0.8126
# Loss: 0.4588528871536255
# Accuracy: 0.8125701546669006
